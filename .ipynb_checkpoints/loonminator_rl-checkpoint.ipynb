# %%
import numpy as np
import gym
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam
from rl.agents.cem import CEMAgent
from rl.memory import EpisodeParameterMemory

# config
# import loonminator game environment
import gym_loon
ENV_NAME = 'loon-v0'
intervals = 100
# how long to train for
nb_steps = 10000
batch_size = 500
# how many nodes per hidden layer
hidden_size = 200
# render not yet implemented
visual = False

# automatic config
env = gym.make(ENV_NAME)
np.random.seed(1)
env.seed(1)
# define actions to take
nb_actions = env.action_space.n
obs_dim = env.observation_space.shape[0]

# create network
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(hidden_size))
model.add(Activation('relu'))
model.add(Dense(hidden_size))
model.add(Activation('relu'))
model.add(Dense(hidden_size))
model.add(Activation('relu'))
model.add(Dense(hidden_size))
model.add(Activation('relu'))
model.add(Dense(hidden_size))
model.add(Activation('relu'))
model.add(Dense(hidden_size))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('softmax'))
print(model.summary())

# compile agent
memory = EpisodeParameterMemory(limit=1000, window_length=1)
cem = CEMAgent(model=model, nb_actions=nb_actions, memory=memory,
               batch_size=batch_size, nb_steps_warmup=nb_steps * .02,
               train_interval=intervals, elite_frac=0.2)
cem.compile()

# train
# increase verbose for more info
cem.fit(env, nb_steps=nb_steps, log_interval=intervals, visualize=False, verbose=1)

# save model after training
cem.save_weights('cem_{}_params.h5f'.format(ENV_NAME), overwrite=True)

# test for five games
cem.test(env, nb_episodes=5, visualize=visual)
# Out:
# /anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               400
# _________________________________________________________________
# activation_1 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_2 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_3 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_4 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_5 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_6 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                2010
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 203,410
# Trainable params: 203,410
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1055.2864
# 1 episodes - episode_reward: 105528.637 [105528.637, 105528.637]
#
# Interval 2 (100 steps performed)
# 100/100 [==============================] - 0s 818us/step - reward: 1171.5813
# 1 episodes - episode_reward: 117158.131 [117158.131, 117158.131]
#
# Interval 3 (200 steps performed)
# 100/100 [==============================] - 0s 771us/step - reward: 877.6021
# 1 episodes - episode_reward: 87760.210 [87760.210, 87760.210]
#
# Interval 4 (300 steps performed)
# 100/100 [==============================] - 0s 807us/step - reward: 922.3320
# 1 episodes - episode_reward: 92233.202 [92233.202, 92233.202]
#
# Interval 5 (400 steps performed)
# 100/100 [==============================] - 0s 966us/step - reward: 1117.9773
# 1 episodes - episode_reward: 111797.728 [111797.728, 111797.728]
#
# Interval 6 (500 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1141.8857
# 1 episodes - episode_reward: 114188.568 [114188.568, 114188.568]
#
# Interval 7 (600 steps performed)
# 100/100 [==============================] - 0s 913us/step - reward: 996.4718
# 1 episodes - episode_reward: 99647.181 [99647.181, 99647.181]
#
# Interval 8 (700 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1138.5424
# 1 episodes - episode_reward: 113854.239 [113854.239, 113854.239]
#
# Interval 9 (800 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1080.4975
# 1 episodes - episode_reward: 108049.748 [108049.748, 108049.748]
#
# Interval 10 (900 steps performed)
# 100/100 [==============================] - 0s 866us/step - reward: 1078.0493
# 1 episodes - episode_reward: 107804.934 [107804.934, 107804.934]
#
# Interval 11 (1000 steps performed)
# 100/100 [==============================] - 0s 837us/step - reward: 1041.4818
# 1 episodes - episode_reward: 104148.178 [104148.178, 104148.178]
#
# Interval 12 (1100 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1138.8885
# 1 episodes - episode_reward: 113888.851 [113888.851, 113888.851]
#
# Interval 13 (1200 steps performed)
# 100/100 [==============================] - 0s 991us/step - reward: 1138.2002
# 1 episodes - episode_reward: 113820.018 [113820.018, 113820.018]
#
# Interval 14 (1300 steps performed)
# 100/100 [==============================] - 0s 995us/step - reward: 954.4307
# 1 episodes - episode_reward: 95443.073 [95443.073, 95443.073]
#
# Interval 15 (1400 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1035.4094
# 1 episodes - episode_reward: 103540.942 [103540.942, 103540.942]
#
# Interval 16 (1500 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 960.5562
# 1 episodes - episode_reward: 96055.622 [96055.622, 96055.622]
#
# Interval 17 (1600 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1052.4862
# 1 episodes - episode_reward: 105248.622 [105248.622, 105248.622]
#
# Interval 18 (1700 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1181.4697
# 1 episodes - episode_reward: 118146.970 [118146.970, 118146.970]
#
# Interval 19 (1800 steps performed)
# 100/100 [==============================] - 0s 798us/step - reward: 1081.9853
# 1 episodes - episode_reward: 108198.529 [108198.529, 108198.529]
#
# Interval 20 (1900 steps performed)
# 100/100 [==============================] - 0s 777us/step - reward: 1146.1256
# 1 episodes - episode_reward: 114612.556 [114612.556, 114612.556]
#
# Interval 21 (2000 steps performed)
# 100/100 [==============================] - 0s 758us/step - reward: 1135.0315
# 1 episodes - episode_reward: 113503.148 [113503.148, 113503.148]
#
# Interval 22 (2100 steps performed)
# 100/100 [==============================] - 0s 808us/step - reward: 1042.1176
# 1 episodes - episode_reward: 104211.755 [104211.755, 104211.755]
#
# Interval 23 (2200 steps performed)
# 100/100 [==============================] - 0s 806us/step - reward: 995.1176
# 1 episodes - episode_reward: 99511.757 [99511.757, 99511.757]
#
# Interval 24 (2300 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1185.9815
# 1 episodes - episode_reward: 118598.149 [118598.149, 118598.149]
#
# Interval 25 (2400 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1118.4636
# 1 episodes - episode_reward: 111846.358 [111846.358, 111846.358]
#
# Interval 26 (2500 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1112.4356
# 1 episodes - episode_reward: 111243.560 [111243.560, 111243.560]
#
# Interval 27 (2600 steps performed)
# 100/100 [==============================] - 0s 909us/step - reward: 1214.1432
# 1 episodes - episode_reward: 121414.318 [121414.318, 121414.318]
#
# Interval 28 (2700 steps performed)
# 100/100 [==============================] - 0s 901us/step - reward: 1037.8571
# 1 episodes - episode_reward: 103785.705 [103785.705, 103785.705]
#
# Interval 29 (2800 steps performed)
# 100/100 [==============================] - 0s 794us/step - reward: 1117.1541
# 1 episodes - episode_reward: 111715.409 [111715.409, 111715.409]
#
# Interval 30 (2900 steps performed)
# 100/100 [==============================] - 0s 844us/step - reward: 1185.8431
# 1 episodes - episode_reward: 118584.306 [118584.306, 118584.306]
#
# Interval 31 (3000 steps performed)
# 100/100 [==============================] - 0s 871us/step - reward: 1035.9688
# 1 episodes - episode_reward: 103596.879 [103596.879, 103596.879]
#
# Interval 32 (3100 steps performed)
# 100/100 [==============================] - 0s 978us/step - reward: 1047.3794
# 1 episodes - episode_reward: 104737.944 [104737.944, 104737.944]
#
# Interval 33 (3200 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1169.1853
# 1 episodes - episode_reward: 116918.534 [116918.534, 116918.534]
#
# Interval 34 (3300 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1134.9875
# 1 episodes - episode_reward: 113498.748 [113498.748, 113498.748]
#
# Interval 35 (3400 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 988.7273
# 1 episodes - episode_reward: 98872.734 [98872.734, 98872.734]
#
# Interval 36 (3500 steps performed)
# 100/100 [==============================] - 0s 999us/step - reward: 1141.6968
# 1 episodes - episode_reward: 114169.677 [114169.677, 114169.677]
#
# Interval 37 (3600 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1147.3654
# 1 episodes - episode_reward: 114736.538 [114736.538, 114736.538]
#
# Interval 38 (3700 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1057.7492
# 1 episodes - episode_reward: 105774.916 [105774.916, 105774.916]
#
# Interval 39 (3800 steps performed)
# 100/100 [==============================] - 0s 938us/step - reward: 1141.0549
# 1 episodes - episode_reward: 114105.494 [114105.494, 114105.494]
#
# Interval 40 (3900 steps performed)
# 100/100 [==============================] - 0s 862us/step - reward: 1115.1430
# 1 episodes - episode_reward: 111514.304 [111514.304, 111514.304]
#
# Interval 41 (4000 steps performed)
# 100/100 [==============================] - 0s 846us/step - reward: 1064.8098
# 1 episodes - episode_reward: 106480.976 [106480.976, 106480.976]
#
# Interval 42 (4100 steps performed)
# 100/100 [==============================] - 0s 843us/step - reward: 1119.8336
# 1 episodes - episode_reward: 111983.360 [111983.360, 111983.360]
#
# Interval 43 (4200 steps performed)
# 100/100 [==============================] - 0s 851us/step - reward: 1159.7293
# 1 episodes - episode_reward: 115972.927 [115972.927, 115972.927]
#
# Interval 44 (4300 steps performed)
# 100/100 [==============================] - 0s 830us/step - reward: 1175.6783
# 1 episodes - episode_reward: 117567.830 [117567.830, 117567.830]
#
# Interval 45 (4400 steps performed)
# 100/100 [==============================] - 0s 820us/step - reward: 1078.9937
# 1 episodes - episode_reward: 107899.374 [107899.374, 107899.374]
#
# Interval 46 (4500 steps performed)
# 100/100 [==============================] - 0s 766us/step - reward: 922.6333
# 1 episodes - episode_reward: 92263.333 [92263.333, 92263.333]
#
# Interval 47 (4600 steps performed)
# 100/100 [==============================] - 0s 742us/step - reward: 1168.7163
# 1 episodes - episode_reward: 116871.633 [116871.633, 116871.633]
#
# Interval 48 (4700 steps performed)
# 100/100 [==============================] - 0s 908us/step - reward: 1161.5462
# 1 episodes - episode_reward: 116154.624 [116154.624, 116154.624]
#
# Interval 49 (4800 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1089.5035
# 1 episodes - episode_reward: 108950.349 [108950.349, 108950.349]
#
# Interval 50 (4900 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1136.2597
# 1 episodes - episode_reward: 113625.971 [113625.971, 113625.971]
#
# Interval 51 (5000 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1138.9168
# 1 episodes - episode_reward: 113891.676 [113891.676, 113891.676]
#
# Interval 52 (5100 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1081.8531
# 1 episodes - episode_reward: 108185.310 [108185.310, 108185.310]
#
# Interval 53 (5200 steps performed)
# 100/100 [==============================] - 0s 998us/step - reward: 1061.7235
# 1 episodes - episode_reward: 106172.345 [106172.345, 106172.345]
#
# Interval 54 (5300 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1135.4750
# 1 episodes - episode_reward: 113547.502 [113547.502, 113547.502]
#
# Interval 55 (5400 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1040.7859
# 1 episodes - episode_reward: 104078.586 [104078.586, 104078.586]
#
# Interval 56 (5500 steps performed)
# 100/100 [==============================] - 0s 850us/step - reward: 1178.3379
# 1 episodes - episode_reward: 117833.793 [117833.793, 117833.793]
#
# Interval 57 (5600 steps performed)
# 100/100 [==============================] - 0s 737us/step - reward: 1022.0489
# 1 episodes - episode_reward: 102204.894 [102204.894, 102204.894]
#
# Interval 58 (5700 steps performed)
# 100/100 [==============================] - 0s 724us/step - reward: 1025.9799
# 1 episodes - episode_reward: 102597.986 [102597.986, 102597.986]
#
# Interval 59 (5800 steps performed)
# 100/100 [==============================] - 0s 709us/step - reward: 1135.6506
# 1 episodes - episode_reward: 113565.063 [113565.063, 113565.063]
#
# Interval 60 (5900 steps performed)
# 100/100 [==============================] - 0s 717us/step - reward: 1151.5893
# 1 episodes - episode_reward: 115158.927 [115158.927, 115158.927]
#
# Interval 61 (6000 steps performed)
# 100/100 [==============================] - 0s 720us/step - reward: 1082.2316
# 1 episodes - episode_reward: 108223.165 [108223.165, 108223.165]
#
# Interval 62 (6100 steps performed)
# 100/100 [==============================] - 0s 750us/step - reward: 1138.5860
# 1 episodes - episode_reward: 113858.598 [113858.598, 113858.598]
#
# Interval 63 (6200 steps performed)
# 100/100 [==============================] - 0s 979us/step - reward: 1142.8958
# 1 episodes - episode_reward: 114289.579 [114289.579, 114289.579]
#
# Interval 64 (6300 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1102.6384
# 1 episodes - episode_reward: 110263.837 [110263.837, 110263.837]
#
# Interval 65 (6400 steps performed)
# 100/100 [==============================] - 0s 818us/step - reward: 1150.6039
# 1 episodes - episode_reward: 115060.387 [115060.387, 115060.387]
#
# Interval 66 (6500 steps performed)
# 100/100 [==============================] - 0s 737us/step - reward: 1184.0158
# 1 episodes - episode_reward: 118401.575 [118401.575, 118401.575]
#
# Interval 67 (6600 steps performed)
# 100/100 [==============================] - 0s 719us/step - reward: 1121.8226
# 1 episodes - episode_reward: 112182.261 [112182.261, 112182.261]
#
# Interval 68 (6700 steps performed)
# 100/100 [==============================] - 0s 727us/step - reward: 1019.9439
# 1 episodes - episode_reward: 101994.393 [101994.393, 101994.393]
#
# Interval 69 (6800 steps performed)
# 100/100 [==============================] - 0s 1ms/step - reward: 1135.5048
# 1 episodes - episode_reward: 113550.484 [113550.484, 113550.484]
#
# Interval 70 (6900 steps performed)
# 100/100 [==============================] - 0s 977us/step - reward: 1008.0405
# 1 episodes - episode_reward: 100804.051 [100804.051, 100804.051]
#
# Interval 71 (7000 steps performed)
# 100/100 [==============================] - 0s 753us/step - reward: 1160.3043
# 1 episodes - episode_reward: 116030.429 [116030.429, 116030.429]
#
# Interval 72 (7100 steps performed)
# 100/100 [==============================] - 0s 718us/step - reward: 1133.2847
# 1 episodes - episode_reward: 113328.467 [113328.467, 113328.467]
#
# Interval 73 (7200 steps performed)
# 100/100 [==============================] - 0s 793us/step - reward: 1119.1794
# 1 episodes - episode_reward: 111917.943 [111917.943, 111917.943]
#
# Interval 74 (7300 steps performed)
# 100/100 [==============================] - 0s 926us/step - reward: 1103.3002
# 1 episodes - episode_reward: 110330.017 [110330.017, 110330.017]
#
# Interval 75 (7400 steps performed)
# 100/100 [==============================] - 0s 848us/step - reward: 1133.1676
# 1 episodes - episode_reward: 113316.763 [113316.763, 113316.763]
#
# Interval 76 (7500 steps performed)
# 100/100 [==============================] - 0s 787us/step - reward: 1111.6934
# 1 episodes - episode_reward: 111169.341 [111169.341, 111169.341]
#
# Interval 77 (7600 steps performed)
# 100/100 [==============================] - 0s 786us/step - reward: 1039.2804
# 1 episodes - episode_reward: 103928.038 [103928.038, 103928.038]
#
# Interval 78 (7700 steps performed)
# 100/100 [==============================] - 0s 730us/step - reward: 949.7100
# 1 episodes - episode_reward: 94970.999 [94970.999, 94970.999]
#
# Interval 79 (7800 steps performed)
# 100/100 [==============================] - 0s 733us/step - reward: 1227.6322
# 1 episodes - episode_reward: 122763.223 [122763.223, 122763.223]
#
# Interval 80 (7900 steps performed)
# 100/100 [==============================] - 0s 750us/step - reward: 1149.6056
# 1 episodes - episode_reward: 114960.565 [114960.565, 114960.565]
#
# Interval 81 (8000 steps performed)
# 100/100 [==============================] - 0s 910us/step - reward: 1149.0106
# 1 episodes - episode_reward: 114901.058 [114901.058, 114901.058]
#
# Interval 82 (8100 steps performed)
# 100/100 [==============================] - 0s 847us/step - reward: 1116.8908
# 1 episodes - episode_reward: 111689.077 [111689.077, 111689.077]
#
# Interval 83 (8200 steps performed)
# 100/100 [==============================] - 0s 799us/step - reward: 1148.6969
# 1 episodes - episode_reward: 114869.690 [114869.690, 114869.690]
#
# Interval 84 (8300 steps performed)
# 100/100 [==============================] - 0s 729us/step - reward: 1065.6729
# 1 episodes - episode_reward: 106567.294 [106567.294, 106567.294]
#
# Interval 85 (8400 steps performed)
# 100/100 [==============================] - 0s 722us/step - reward: 1153.0146
# 1 episodes - episode_reward: 115301.456 [115301.456, 115301.456]
#
# Interval 86 (8500 steps performed)
# 100/100 [==============================] - 0s 732us/step - reward: 1055.2045
# 1 episodes - episode_reward: 105520.447 [105520.447, 105520.447]
#
# Interval 87 (8600 steps performed)
# 100/100 [==============================] - 0s 841us/step - reward: 992.8800
# 1 episodes - episode_reward: 99287.995 [99287.995, 99287.995]
#
# Interval 88 (8700 steps performed)
# 100/100 [==============================] - 0s 865us/step - reward: 1077.7977
# 1 episodes - episode_reward: 107779.765 [107779.765, 107779.765]
#
# Interval 89 (8800 steps performed)
# 100/100 [==============================] - 0s 832us/step - reward: 1026.3713
# 1 episodes - episode_reward: 102637.129 [102637.129, 102637.129]
#
# Interval 90 (8900 steps performed)
# 100/100 [==============================] - 0s 761us/step - reward: 1081.1196
# 1 episodes - episode_reward: 108111.962 [108111.962, 108111.962]
#
# Interval 91 (9000 steps performed)
# 100/100 [==============================] - 0s 769us/step - reward: 1023.5653
# 1 episodes - episode_reward: 102356.534 [102356.534, 102356.534]
#
# Interval 92 (9100 steps performed)
# 100/100 [==============================] - 0s 720us/step - reward: 1093.3447
# 1 episodes - episode_reward: 109334.470 [109334.470, 109334.470]
#
# Interval 93 (9200 steps performed)
# 100/100 [==============================] - 0s 717us/step - reward: 1105.9509
# 1 episodes - episode_reward: 110595.092 [110595.092, 110595.092]
#
# Interval 94 (9300 steps performed)
# 100/100 [==============================] - 0s 736us/step - reward: 1183.8684
# 1 episodes - episode_reward: 118386.836 [118386.836, 118386.836]
#
# Interval 95 (9400 steps performed)
# 100/100 [==============================] - 0s 748us/step - reward: 1098.1539
# 1 episodes - episode_reward: 109815.395 [109815.395, 109815.395]
#
# Interval 96 (9500 steps performed)
# 100/100 [==============================] - 0s 943us/step - reward: 1150.8820
# 1 episodes - episode_reward: 115088.202 [115088.202, 115088.202]
#
# Interval 97 (9600 steps performed)
# 100/100 [==============================] - 0s 873us/step - reward: 1139.2300
# 1 episodes - episode_reward: 113922.995 [113922.995, 113922.995]
#
# Interval 98 (9700 steps performed)
# 100/100 [==============================] - 0s 788us/step - reward: 1075.5787
# 1 episodes - episode_reward: 107557.873 [107557.873, 107557.873]
#
# Interval 99 (9800 steps performed)
# 100/100 [==============================] - 0s 759us/step - reward: 1120.5064
# 1 episodes - episode_reward: 112050.643 [112050.643, 112050.643]
#
# Interval 100 (9900 steps performed)
# 100/100 [==============================] - 0s 729us/step - reward: 944.9384
# done, took 8.994 seconds
# Testing for 5 episodes ...
# Episode 1: reward: 119672.159, steps: 100
# Episode 2: reward: 124105.831, steps: 100
# Episode 3: reward: 100012.907, steps: 100
# Episode 4: reward: 117604.807, steps: 100
# Episode 5: reward: 93986.830, steps: 100
